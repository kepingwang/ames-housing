# %% [markdown]
# ### Exploration of Ames housing dataset

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
ls ../data/
# Out:
# AmesHousing.csv         data_description.txt
# AmesResidentialMap.pdf  decock.pdf

# %%
df = pd.read_csv('../data/AmesHousing.csv')
df.columns = df.columns.map(lambda x: x.replace(" ", "").replace("/",""))
df.head()
# Out:
#    Order        PID  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0      1  526301100          20       RL        141.0    31770   Pave   NaN
# 1      2  526350040          20       RH         80.0    11622   Pave   NaN
# 2      3  526351010          20       RL         81.0    14267   Pave   NaN
# 3      4  526353030          20       RL         93.0    11160   Pave   NaN
# 4      5  527105010          60       RL         74.0    13830   Pave   NaN
#
#   LotShape LandContour    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0      IR1         Lvl    ...            0    NaN    NaN         NaN       0
# 1      Reg         Lvl    ...            0    NaN  MnPrv         NaN       0
# 2      IR1         Lvl    ...            0    NaN    NaN        Gar2   12500
# 3      Reg         Lvl    ...            0    NaN    NaN         NaN       0
# 4      IR1         Lvl    ...            0    NaN  MnPrv         NaN       0
#
#   MoSold YrSold SaleType  SaleCondition  SalePrice
# 0      5   2010      WD          Normal     215000
# 1      6   2010      WD          Normal     105000
# 2      6   2010      WD          Normal     172000
# 3      4   2010      WD          Normal     244000
# 4      3   2010      WD          Normal     189900
#
# [5 rows x 82 columns]

# %%
df.describe()
# Out:
#             Order           PID   MSSubClass  LotFrontage        LotArea  \
# count  2930.00000  2.930000e+03  2930.000000  2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372    69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025    23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000    21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000    58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000    68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000    80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000   313.000000  215245.000000
#
#        OverallQual  OverallCond    YearBuilt  YearRemod/Add   MasVnrArea  \
# count  2930.000000  2930.000000  2930.000000    2930.000000  2907.000000
# mean      6.094881     5.563140  1971.356314    1984.266553   101.896801
# std       1.411026     1.111537    30.245361      20.860286   179.112611
# min       1.000000     1.000000  1872.000000    1950.000000     0.000000
# 25%       5.000000     5.000000  1954.000000    1965.000000     0.000000
# 50%       6.000000     5.000000  1973.000000    1993.000000     0.000000
# 75%       7.000000     6.000000  2001.000000    2004.000000   164.000000
# max      10.000000     9.000000  2010.000000    2010.000000  1600.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        2930.000000  2930.000000    2930.000000  2930.000000
# mean       ...          93.751877    47.533447      23.011604     2.592491
# std        ...         126.361562    67.483400      64.139059    25.141331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    27.000000       0.000000     0.000000
# 75%        ...         168.000000    70.000000       0.000000     0.000000
# max        ...        1424.000000   742.000000    1012.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  2930.000000  2930.000000   2930.000000  2930.000000  2930.000000
# mean     16.002048     2.243345     50.635154     6.216041  2007.790444
# std      56.087370    35.597181    566.344288     2.714492     1.316613
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     576.000000   800.000000  17000.000000    12.000000  2010.000000
#
#            SalePrice
# count    2930.000000
# mean   180796.060068
# std     79886.692357
# min     12789.000000
# 25%    129500.000000
# 50%    160000.000000
# 75%    213500.000000
# max    755000.000000
#
# [8 rows x 39 columns]

# %%
df.columns.sort_values()
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley', 'BedroomAbvGr',
#        'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath',
#        'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st',
#        'Exterior2nd', 'Fence', 'FireplaceQu', 'Fireplaces', 'Foundation',
#        'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt', 'GrLivArea',
#        'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenAbvGr',
#        'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig',
#        'LotFrontage', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning',
#        'MasVnrArea', 'MasVnrType', 'MiscFeature', 'MiscVal', 'MoSold',
#        'Neighborhood', 'OpenPorchSF', 'Order', 'OverallCond', 'OverallQual',
#        'PID', 'PavedDrive', 'PoolArea', 'PoolQC', 'RoofMatl', 'RoofStyle',
#        'SaleCondition', 'SalePrice', 'SaleType', 'ScreenPorch', 'Street',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 500)
print(df.dtypes.sort_values())
# Out:
# Order              int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# 1stFlrSF           int64
# Fireplaces         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# WoodDeckSF         int64
# YearRemodAdd       int64
# SalePrice          int64
# PID                int64
# MSSubClass         int64
# OverallQual        int64
# YearBuilt          int64
# OverallCond        int64
# LotArea            int64
# BsmtUnfSF        float64
# TotalBsmtSF      float64
# BsmtFinSF2       float64
# GarageArea       float64
# BsmtFinSF1       float64
# GarageCars       float64
# LotFrontage      float64
# BsmtHalfBath     float64
# MasVnrArea       float64
# GarageYrBlt      float64
# BsmtFullBath     float64
# GarageFinish      object
# GarageType        object
# GarageQual        object
# RoofStyle         object
# PavedDrive        object
# LandContour       object
# FireplaceQu       object
# LotShape          object
# Alley             object
# Street            object
# PoolQC            object
# Fence             object
# MiscFeature       object
# MSZoning          object
# SaleType          object
# GarageCond        object
# Utilities         object
# Condition1        object
# LotConfig         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# Functional        object
# BsmtFinType1      object
# SaleCondition     object
# HeatingQC         object
# CentralAir        object
# Electrical        object
# HouseStyle        object
# BldgType          object
# Condition2        object
# Neighborhood      object
# LandSlope         object
# KitchenQual       object
# BsmtFinType2      object
# Heating           object
# dtype: object

# %%
df['SalePrice'].hist(bins=30)
plt.title('sale price distribution')
plt.show()

# %%
salePrice = df['SalePrice'].copy()
salePrice.sort_values()
# Out:
# 181      12789
# 1553     13100
# 726      34900
# 2843     35000
# 2880     35311
# 709      37900
# 1901     39300
# 1555     40000
# 727      44000
# 708      45000
# 1302     46500
# 2043     50000
# 307      50138
# 2879     51689
# 1220     52000
# 2689     52500
# 206      55000
# 1321     55000
# 1546     55000
# 306      55993
# 945      57625
# 287      58500
# 720      58500
# 662      59000
# 790      60000
# 742      60000
# 907      60000
# 765      61000
# 2184     61500
# 2653     61500
#          ...
# 2329    457347
# 1059    460000
# 421     462000
# 2382    465000
# 1763    466500
# 513     468000
# 2341    470000
# 2666    475000
# 1425    475000
# 1695    479069
# 422     485000
# 1691    492000
# 46      500000
# 1701    500067
# 366     501837
# 2334    535000
# 15      538000
# 2330    545224
# 456     552000
# 423     555000
# 2332    556581
# 433     582933
# 2450    584500
# 1637    591587
# 432     610000
# 44      611657
# 1063    615000
# 2445    625000
# 1760    745000
# 1767    755000
# Name: SalePrice, dtype: int64

# %% [markdown]
# ### Numerical Features

# %%
corr = df.select_dtypes(include=['float64','int64']).iloc[:, 2:].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(corr, vmax=1, square=True)
plt.show()

# %%
corr
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.420135 -0.204613     0.039419    -0.067349
# LotFrontage     -0.420135     1.000000  0.491313     0.212042    -0.074448
# LotArea         -0.204613     0.491313  1.000000     0.097188    -0.034759
# OverallQual      0.039419     0.212042  0.097188     1.000000    -0.094812
# OverallCond     -0.067349    -0.074448 -0.034759    -0.094812     1.000000
# YearBuilt        0.036579     0.121562  0.023258     0.597027    -0.368773
# YearRemod/Add    0.043397     0.091712  0.021682     0.569609     0.047680
# MasVnrArea       0.002730     0.222407  0.126830     0.429418    -0.135340
# BsmtFinSF1      -0.060075     0.215583  0.191555     0.284118    -0.050935
# BsmtFinSF2      -0.070946     0.045999  0.083150    -0.041287     0.041134
# BsmtUnfSF       -0.130421     0.116743  0.023658     0.270058    -0.136819
# TotalBsmtSF     -0.219445     0.353773  0.253589     0.547294    -0.173344
# 1stFlrSF        -0.247828     0.457391  0.332235     0.477837    -0.157052
# 2ndFlrSF         0.304237     0.029187  0.032996     0.241402     0.006218
# LowQualFinSF     0.025765     0.005249  0.000812    -0.048680     0.009175
# GrLivArea        0.068061     0.383822  0.285599     0.570556    -0.115643
# BsmtFullBath     0.013701     0.108915  0.125877     0.167858    -0.042766
# BsmtHalfBath    -0.003329    -0.024724  0.026903    -0.041647     0.084455
# FullBath         0.134631     0.184521  0.127433     0.522263    -0.214316
# HalfBath         0.175879     0.041880  0.035497     0.268853    -0.088127
# BedroomAbvGr    -0.019208     0.240442  0.136569     0.063291    -0.006137
# KitchenAbvGr     0.257698     0.005407 -0.020301    -0.159744    -0.086386
# TotRmsAbvGrd     0.031898     0.353137  0.216597     0.380693    -0.089816
# Fireplaces      -0.049955     0.257255  0.256989     0.393007    -0.031702
# GarageYrBlt      0.088754     0.076306 -0.008952     0.570569    -0.326017
# GarageCars      -0.045883     0.308706  0.179512     0.599545    -0.181557
# GarageArea      -0.103239     0.358505  0.212822     0.563503    -0.153754
# WoodDeckSF      -0.017310     0.120084  0.157212     0.255663     0.020344
# OpenPorchSF     -0.014823     0.163040  0.103760     0.298412    -0.068934
# EnclosedPorch   -0.022866     0.012758  0.021868    -0.140332     0.071459
# 3SsnPorch       -0.037956     0.028564  0.016243     0.018240     0.043852
# ScreenPorch     -0.050614     0.076666  0.055044     0.041615     0.044055
# PoolArea        -0.003434     0.173947  0.093775     0.030399    -0.016787
# MiscVal         -0.029254     0.044476  0.069188     0.005179     0.034056
# MoSold           0.000350     0.011085  0.003859     0.031103    -0.007295
# YrSold          -0.017905    -0.007547 -0.023085    -0.020719     0.031207
# SalePrice       -0.085092     0.357318  0.266549     0.799262    -0.101697
#
#                YearBuilt  YearRemod/Add  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass      0.036579       0.043397    0.002730   -0.060075   -0.070946
# LotFrontage     0.121562       0.091712    0.222407    0.215583    0.045999
# LotArea         0.023258       0.021682    0.126830    0.191555    0.083150
# OverallQual     0.597027       0.569609    0.429418    0.284118   -0.041287
# OverallCond    -0.368773       0.047680   -0.135340   -0.050935    0.041134
# YearBuilt       1.000000       0.612095    0.313292    0.279870   -0.027415
# YearRemod/Add   0.612095       1.000000    0.196928    0.151790   -0.062129
# MasVnrArea      0.313292       0.196928    1.000000    0.301872   -0.016019
# BsmtFinSF1      0.279870       0.151790    0.301872    1.000000   -0.054129
# BsmtFinSF2     -0.027415      -0.062129   -0.016019   -0.054129    1.000000
# BsmtUnfSF       0.128998       0.164805    0.091668   -0.477875   -0.238617
# TotalBsmtSF     0.407526       0.297481    0.397040    0.536547    0.089958
# 1stFlrSF        0.310463       0.242108    0.395736    0.457472    0.084651
# 2ndFlrSF        0.016828       0.158939    0.121805   -0.164014   -0.098278
# LowQualFinSF   -0.144282      -0.060365   -0.057701   -0.066173   -0.004999
# GrLivArea       0.241726       0.316855    0.403611    0.209633   -0.018120
# BsmtFullBath    0.211849       0.134387    0.140113    0.640020    0.163512
# BsmtHalfBath   -0.030626      -0.046292    0.015421    0.077548    0.099101
# FullBath        0.469406       0.457266    0.260153    0.077772   -0.076380
# HalfBath        0.269268       0.211771    0.192965   -0.008457   -0.033084
# BedroomAbvGr   -0.055093      -0.021536    0.080546   -0.118959   -0.033143
# KitchenAbvGr   -0.137852      -0.142404   -0.050998   -0.086738   -0.037885
# TotRmsAbvGrd    0.111919       0.197528    0.279563    0.047631   -0.049465
# Fireplaces      0.170672       0.133322    0.272068    0.295882    0.067098
# GarageYrBlt     0.834849       0.652310    0.254784    0.194238   -0.068507
# GarageCars      0.537443       0.425403    0.360159    0.255483   -0.014469
# GarageArea      0.480131       0.376438    0.373458    0.309876    0.003318
# WoodDeckSF      0.228964       0.217857    0.165467    0.224010    0.098528
# OpenPorchSF     0.198365       0.241748    0.143748    0.124947   -0.005587
# EnclosedPorch  -0.374364      -0.220383   -0.110787   -0.100455    0.032380
# 3SsnPorch       0.015803       0.037412    0.013778    0.050541   -0.023325
# ScreenPorch    -0.041436      -0.046888    0.065643    0.095874    0.062951
# PoolArea        0.002213      -0.011410    0.004617    0.084140    0.044398
# MiscVal        -0.011011      -0.003132    0.044934    0.092886   -0.005204
# MoSold          0.014577       0.018048   -0.000276   -0.001155   -0.009484
# YrSold         -0.013197       0.032652   -0.017715    0.022397    0.007105
# SalePrice       0.558426       0.532974    0.508285    0.432914    0.005891
#
#                  ...      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# MSSubClass       ...       -0.017310    -0.014823      -0.022866  -0.037956
# LotFrontage      ...        0.120084     0.163040       0.012758   0.028564
# LotArea          ...        0.157212     0.103760       0.021868   0.016243
# OverallQual      ...        0.255663     0.298412      -0.140332   0.018240
# OverallCond      ...        0.020344    -0.068934       0.071459   0.043852
# YearBuilt        ...        0.228964     0.198365      -0.374364   0.015803
# YearRemod/Add    ...        0.217857     0.241748      -0.220383   0.037412
# MasVnrArea       ...        0.165467     0.143748      -0.110787   0.013778
# BsmtFinSF1       ...        0.224010     0.124947      -0.100455   0.050541
# BsmtFinSF2       ...        0.098528    -0.005587       0.032380  -0.023325
# BsmtUnfSF        ...       -0.039621     0.118880       0.006229  -0.005446
# TotalBsmtSF      ...        0.229931     0.245627      -0.085225   0.037871
# 1stFlrSF         ...        0.227131     0.238041      -0.065713   0.044061
# 2ndFlrSF         ...        0.089097     0.184538       0.055429  -0.032172
# LowQualFinSF     ...       -0.015646    -0.000761       0.087326  -0.004505
# GrLivArea        ...        0.250153     0.340857       0.004030   0.006481
# BsmtFullBath     ...        0.186945     0.082268      -0.069235   0.027034
# BsmtHalfBath     ...        0.051430    -0.035069      -0.009334   0.026954
# FullBath         ...        0.179574     0.258675      -0.117795   0.015435
# HalfBath         ...        0.115212     0.180704      -0.081312  -0.023231
# BedroomAbvGr     ...        0.029711     0.083650       0.052115  -0.047151
# KitchenAbvGr     ...       -0.087410    -0.068283       0.027911  -0.021379
# TotRmsAbvGrd     ...        0.154735     0.235684       0.017221  -0.025097
# Fireplaces       ...        0.228064     0.159637      -0.000250   0.018414
# GarageYrBlt      ...        0.221991     0.231240      -0.300879   0.020617
# GarageCars       ...        0.241226     0.204182      -0.132840   0.023345
# GarageArea       ...        0.238371     0.232912      -0.106272   0.029458
# WoodDeckSF       ...        1.000000     0.039243      -0.119136  -0.003967
# OpenPorchSF      ...        0.039243     1.000000      -0.059875  -0.009458
# EnclosedPorch    ...       -0.119136    -0.059875       1.000000  -0.032674
# 3SsnPorch        ...       -0.003967    -0.009458      -0.032674   1.000000
# ScreenPorch      ...       -0.052191     0.047548      -0.063965  -0.029430
# PoolArea         ...        0.094156     0.064135       0.092596  -0.006501
# MiscVal          ...        0.056820     0.077254       0.008773  -0.000753
# MoSold           ...        0.016974     0.033651      -0.021324   0.027229
# YrSold           ...        0.000882    -0.037467      -0.000505   0.022668
# SalePrice        ...        0.327143     0.312951      -0.128787   0.032225
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# MSSubClass       -0.050614 -0.003434 -0.029254  0.000350 -0.017905  -0.085092
# LotFrontage       0.076666  0.173947  0.044476  0.011085 -0.007547   0.357318
# LotArea           0.055044  0.093775  0.069188  0.003859 -0.023085   0.266549
# OverallQual       0.041615  0.030399  0.005179  0.031103 -0.020719   0.799262
# OverallCond       0.044055 -0.016787  0.034056 -0.007295  0.031207  -0.101697
# YearBuilt        -0.041436  0.002213 -0.011011  0.014577 -0.013197   0.558426
# YearRemod/Add    -0.046888 -0.011410 -0.003132  0.018048  0.032652   0.532974
# MasVnrArea        0.065643  0.004617  0.044934 -0.000276 -0.017715   0.508285
# BsmtFinSF1        0.095874  0.084140  0.092886 -0.001155  0.022397   0.432914
# BsmtFinSF2        0.062951  0.044398 -0.005204 -0.009484  0.007105   0.005891
# BsmtUnfSF        -0.048083 -0.031999 -0.010166  0.021569 -0.036384   0.182855
# TotalBsmtSF       0.075341  0.072128  0.083904  0.016678 -0.010405   0.632280
# 1stFlrSF          0.098316  0.121821  0.093003  0.040496 -0.013667   0.621676
# 2ndFlrSF          0.011741  0.044602 -0.005078  0.013247 -0.018530   0.269373
# LowQualFinSF      0.006943  0.035200 -0.005939  0.011397 -0.002074  -0.037660
# GrLivArea         0.086804  0.135463  0.067252  0.043665 -0.026489   0.706780
# BsmtFullBath      0.052208  0.043705 -0.004868 -0.003471  0.044905   0.276050
# BsmtHalfBath      0.042326  0.066902  0.036982  0.022699 -0.019529  -0.035835
# FullBath         -0.015130  0.028205 -0.009771  0.046032 -0.004754   0.545604
# HalfBath          0.035990  0.001515  0.026648 -0.001311  0.001561   0.285056
# BedroomAbvGr      0.009250  0.036707  0.000887  0.053677 -0.018008   0.143913
# KitchenAbvGr     -0.056337 -0.013066  0.025145  0.035201  0.035421  -0.119814
# TotRmsAbvGrd      0.033731  0.072103  0.061134  0.043784 -0.030498   0.495474
# Fireplaces        0.168004  0.098449  0.008192  0.032152 -0.007612   0.474558
# GarageYrBlt      -0.062515 -0.014513 -0.009265  0.024498 -0.005159   0.526965
# GarageCars        0.043012  0.030393 -0.016948  0.049847 -0.022488   0.647877
# GarageArea        0.062436  0.053051  0.008466  0.039544 -0.013018   0.640401
# WoodDeckSF       -0.052191  0.094156  0.056820  0.016974  0.000882   0.327143
# OpenPorchSF       0.047548  0.064135  0.077254  0.033651 -0.037467   0.312951
# EnclosedPorch    -0.063965  0.092596  0.008773 -0.021324 -0.000505  -0.128787
# 3SsnPorch        -0.029430 -0.006501 -0.000753  0.027229  0.022668   0.032225
# ScreenPorch       1.000000  0.026383  0.007162  0.028169 -0.006116   0.112151
# PoolArea          0.026383  1.000000  0.011942 -0.042223 -0.052541   0.068403
# MiscVal           0.007162  0.011942  1.000000  0.007333  0.008574  -0.015691
# MoSold            0.028169 -0.042223  0.007333  1.000000 -0.155554   0.035259
# YrSold           -0.006116 -0.052541  0.008574 -0.155554  1.000000  -0.030569
# SalePrice         0.112151  0.068403 -0.015691  0.035259 -0.030569   1.000000
#
# [37 rows x 37 columns]

# %%
sns.regplot(x = 'OverallQual', y = 'SalePrice', data = df, color = 'Orange')
plt.show()

# %%
plt.figure(1)
f, axarr = plt.subplots(3, 2, figsize=(10, 9))
price = df.SalePrice.values
axarr[0, 0].scatter(df.GrLivArea.values, price)
axarr[0, 0].set_title('GrLiveArea')
axarr[0, 1].scatter(df.GarageArea.values, price)
axarr[0, 1].set_title('GarageArea')
axarr[1, 0].scatter(df.TotalBsmtSF.values, price)
axarr[1, 0].set_title('TotalBsmtSF')
axarr[1, 1].scatter(df['1stFlrSF'].values, price)
axarr[1, 1].set_title('1stFlrSF')
axarr[2, 0].scatter(df.TotRmsAbvGrd.values, price)
axarr[2, 0].set_title('TotRmsAbvGrd')
axarr[2, 1].scatter(df.MasVnrArea.values, price)
axarr[2, 1].set_title('MasVnrArea')
f.text(-0.01, 0.5, 'Sale Price', va='center', rotation='vertical', fontsize = 12)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(2, figsize=(9, 7))
plt.subplot(211)
plt.scatter(df.YearBuilt.values, price)
plt.title('YearBuilt')

plt.subplot(212)
plt.scatter(df.YearRemodAdd.values, price)
plt.title('YearRemodAdd')

fig.text(-0.01, 0.5, 'Sale Price', va = 'center', rotation = 'vertical', fontsize = 12)

plt.tight_layout()

# %% [markdown]
# ### Categorical Features

# %%
print(df.select_dtypes(include=['object']).columns.values)
# Out:
# ['MSZoning' 'Street' 'Alley' 'LotShape' 'LandContour' 'Utilities'
#  'LotConfig' 'LandSlope' 'Neighborhood' 'Condition1' 'Condition2'
#  'BldgType' 'HouseStyle' 'RoofStyle' 'RoofMatl' 'Exterior1st' 'Exterior2nd'
#  'MasVnrType' 'ExterQual' 'ExterCond' 'Foundation' 'BsmtQual' 'BsmtCond'
#  'BsmtExposure' 'BsmtFinType1' 'BsmtFinType2' 'Heating' 'HeatingQC'
#  'CentralAir' 'Electrical' 'KitchenQual' 'Functional' 'FireplaceQu'
#  'GarageType' 'GarageFinish' 'GarageQual' 'GarageCond' 'PavedDrive'
#  'PoolQC' 'Fence' 'MiscFeature' 'SaleType' 'SaleCondition']

# %%
# Neighborhood
plt.figure(figsize=(12, 6))
sns.boxplot(x='Neighborhood', y='SalePrice', data=df)
xt = plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
def list_nulls(df):
  for col in df.columns:
    print("NaN count: {}, {}, {}".format(df[col].isnull().sum(), col, df[col].dtype))

# %%
def list_data(df):
  for col in df.columns:
    if df[col].dtype == 'object':
      print(df[col].value_counts())
    else:
      print(df[col].describe())

# %%
def impute_from(df, f_y, f_x, y_upper_limit=None, x_upper_limit=None):
  """
  Input data frame df, impute field f_y from field f_x,
  and return the imputed data frame.
  """
  df = df.copy()
  df_full = df.loc[np.logical_not(df[f_y].isnull())]
  x = df_full.loc[:,f_x]
  y = df_full.loc[:,f_y]
  plt.scatter(x, y)
  plt.xlabel(f_x)
  plt.ylabel(f_y)
  plt.show()
  if x_upper_limit is not None and y_upper_limit is not None:
    mask = (x < x_upper_limit) & (y <= y_upper_limit)
  else:
    mask = np.ones_like(x, dtype=bool)
  p = np.polyfit(x[mask], y[mask], 1) # degree 1
  df.loc[df[f_y].isnull(), f_y] = np.polyval(p, df.loc[df[f_y].isnull(), f_x])
  return df

# %%
df = pd.read_csv('../data/AmesHousing.csv')
df.columns = df.columns.map(lambda x: x.replace(" ", "").replace("/",""))
df = df.drop(['Order','PID'], axis=1)

# %%
df = impute_from(df, "LotFrontage", "LotArea", 150, 25000)

# %%
df = impute_from(df, "GarageYrBlt", "YearBuilt", 2010, 2010)

# %%
# There are many features were NaN should be considered as absence of such 
# property. In other cases I replace NaN with most common value
df.loc[df.Alley.isnull(), 'Alley'] = 'NoAlley'
df.loc[df.MasVnrType.isnull(), 'MasVnrType'] = 'None' # no good
df.loc[df.MasVnrType == 'None', 'MasVnrArea'] = 0
df.loc[df.BsmtQual.isnull(), 'BsmtQual'] = 'NoBsmt'
df.loc[df.BsmtCond.isnull(), 'BsmtCond'] = 'NoBsmt'
df.loc[df.BsmtExposure.isnull(), 'BsmtExposure'] = 'NoBsmt'
df.loc[df.BsmtFinType1.isnull(), 'BsmtFinType1'] = 'NoBsmt'
df.loc[df.BsmtFinType2.isnull(), 'BsmtFinType2'] = 'NoBsmt'
df.loc[df.BsmtFinType1=='NoBsmt', 'BsmtFinSF1'] = 0
df.loc[df.BsmtFinType2=='NoBsmt', 'BsmtFinSF2'] = 0
df.loc[df.BsmtFinSF1.isnull(), 'BsmtFinSF1'] = df.BsmtFinSF1.median()
df.loc[df.BsmtQual=='NoBsmt', 'BsmtUnfSF'] = 0
df.loc[df.BsmtUnfSF.isnull(), 'BsmtUnfSF'] = df.BsmtUnfSF.median()
df.loc[df.BsmtQual=='NoBsmt', 'TotalBsmtSF'] = 0
df.loc[df.FireplaceQu.isnull(), 'FireplaceQu'] = 'NoFireplace'
df.loc[df.GarageType.isnull(), 'GarageType'] = 'NoGarage'
df.loc[df.GarageFinish.isnull(), 'GarageFinish'] = 'NoGarage'
df.loc[df.GarageQual.isnull(), 'GarageQual'] = 'NoGarage'
df.loc[df.GarageCond.isnull(), 'GarageCond'] = 'NoGarage'
df.loc[df.BsmtFullBath.isnull(), 'BsmtFullBath'] = 0
df.loc[df.BsmtHalfBath.isnull(), 'BsmtHalfBath'] = 0
df.loc[df.KitchenQual.isnull(), 'KitchenQual'] = 'TA'
df.loc[df.MSZoning.isnull(), 'MSZoning'] = 'RL'
df.loc[df.Utilities.isnull(), 'Utilities'] = 'AllPub'
df.loc[df.Exterior1st.isnull(), 'Exterior1st'] = 'VinylSd'
df.loc[df.Exterior2nd.isnull(), 'Exterior2nd'] = 'VinylSd'
df.loc[df.Functional.isnull(), 'Functional'] = 'Typ'
df.loc[df.SaleCondition.isnull(), 'SaleCondition'] = 'Normal'
df.loc[df.SaleCondition.isnull(), 'SaleType'] = 'WD'
df.loc[df['PoolQC'].isnull(), 'PoolQC'] = 'NoPool'
df.loc[df['Fence'].isnull(), 'Fence'] = 'NoFence'
df.loc[df['MiscFeature'].isnull(), 'MiscFeature'] = 'None'
df.loc[df['Electrical'].isnull(), 'Electrical'] = 'SBrkr'
# only one is null and it has type Detchd
df.loc[df['GarageArea'].isnull(), 'GarageArea'] = df.loc[df['GarageType']=='Detchd', 'GarageArea'].mean()
df.loc[df['GarageCars'].isnull(), 'GarageCars'] = df.loc[df['GarageType']=='Detchd', 'GarageCars'].median()

# %%
# where we have order we will use numeric
df = df.replace({
  'Utilities': {'AllPub': 1, 'NoSeWa': 0, 'NoSewr': 0, 'ELO': 0},
  'Street': {'Pave': 1, 'Grvl': 0 },
  'FireplaceQu': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1,
                'NoFireplace': 0 
                },
  'Fence': {'GdPrv': 2, 
           'GdWo': 2, 
           'MnPrv': 1, 
           'MnWw': 1,
           'NoFence': 0},
  'ExterQual': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1
                },
  'ExterCond': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1
                },
  'BsmtQual': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1,
                'NoBsmt': 0},
  'BsmtExposure': {'Gd': 3, 
                'Av': 2, 
                'Mn': 1,
                'No': 0,
                'NoBsmt': 0},
  'BsmtCond': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1,
                'NoBsmt': 0},
  'GarageQual': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1,
                'NoGarage': 0},
  'GarageCond': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1,
                'NoGarage': 0},
  'KitchenQual': {'Ex': 5, 
                'Gd': 4, 
                'TA': 3, 
                'Fa': 2,
                'Po': 1},
  'HeatingQC': {'Ex': 5,
                'Gd': 4,
                'TA': 3,
                'Fa': 2,
                'Po': 1},
  'PoolQC': {'Ex': 5,
             'Gd': 4,
             'TA': 3,
             'Fa': 2,
             'NA': 0},
  'Functional': {'Typ': 0,
                'Min1': 1,
                'Min2': 1,
                'Mod': 2,
                'Maj1': 3,
                'Maj2': 4,
                'Sev': 5,
                'Sal': 6}
})

# %%
df = df.replace({
  'MSSubClass': {
    20: 'SubClass_20', 
    30: 'SubClass_30', 
    40: 'SubClass_40', 
    45: 'SubClass_45',
    50: 'SubClass_50', 
    60: 'SubClass_60',
    70: 'SubClass_70',
    75: 'SubClass_75',
    80: 'SubClass_80',
    85: 'SubClass_85',
    90: 'SubClass_90',
   120: 'SubClass_120',
   150: 'SubClass_150',
   160: 'SubClass_160',
   180: 'SubClass_180',
   190: 'SubClass_190'}
})

# %%
list_nulls(df)
# Out:
# NaN count: 0, MSSubClass, object
# NaN count: 0, MSZoning, object
# NaN count: 0, LotFrontage, float64
# NaN count: 0, LotArea, int64
# NaN count: 0, Street, int64
# NaN count: 0, Alley, object
# NaN count: 0, LotShape, object
# NaN count: 0, LandContour, object
# NaN count: 0, Utilities, int64
# NaN count: 0, LotConfig, object
# NaN count: 0, LandSlope, object
# NaN count: 0, Neighborhood, object
# NaN count: 0, Condition1, object
# NaN count: 0, Condition2, object
# NaN count: 0, BldgType, object
# NaN count: 0, HouseStyle, object
# NaN count: 0, OverallQual, int64
# NaN count: 0, OverallCond, int64
# NaN count: 0, YearBuilt, int64
# NaN count: 0, YearRemodAdd, int64
# NaN count: 0, RoofStyle, object
# NaN count: 0, RoofMatl, object
# NaN count: 0, Exterior1st, object
# NaN count: 0, Exterior2nd, object
# NaN count: 0, MasVnrType, object
# NaN count: 0, MasVnrArea, float64
# NaN count: 0, ExterQual, int64
# NaN count: 0, ExterCond, int64
# NaN count: 0, Foundation, object
# NaN count: 0, BsmtQual, int64
# NaN count: 0, BsmtCond, int64
# NaN count: 0, BsmtExposure, int64
# NaN count: 0, BsmtFinType1, object
# NaN count: 0, BsmtFinSF1, float64
# NaN count: 0, BsmtFinType2, object
# NaN count: 0, BsmtFinSF2, float64
# NaN count: 0, BsmtUnfSF, float64
# NaN count: 0, TotalBsmtSF, float64
# NaN count: 0, Heating, object
# NaN count: 0, HeatingQC, int64
# NaN count: 0, CentralAir, object
# NaN count: 0, Electrical, object
# NaN count: 0, 1stFlrSF, int64
# NaN count: 0, 2ndFlrSF, int64
# NaN count: 0, LowQualFinSF, int64
# NaN count: 0, GrLivArea, int64
# NaN count: 0, BsmtFullBath, float64
# NaN count: 0, BsmtHalfBath, float64
# NaN count: 0, FullBath, int64
# NaN count: 0, HalfBath, int64
# NaN count: 0, BedroomAbvGr, int64
# NaN count: 0, KitchenAbvGr, int64
# NaN count: 0, KitchenQual, int64
# NaN count: 0, TotRmsAbvGrd, int64
# NaN count: 0, Functional, int64
# NaN count: 0, Fireplaces, int64
# NaN count: 0, FireplaceQu, int64
# NaN count: 0, GarageType, object
# NaN count: 0, GarageYrBlt, float64
# NaN count: 0, GarageFinish, object
# NaN count: 0, GarageCars, float64
# NaN count: 0, GarageArea, float64
# NaN count: 0, GarageQual, int64
# NaN count: 0, GarageCond, int64
# NaN count: 0, PavedDrive, object
# NaN count: 0, WoodDeckSF, int64
# NaN count: 0, OpenPorchSF, int64
# NaN count: 0, EnclosedPorch, int64
# NaN count: 0, 3SsnPorch, int64
# NaN count: 0, ScreenPorch, int64
# NaN count: 0, PoolArea, int64
# NaN count: 0, PoolQC, object
# NaN count: 0, Fence, int64
# NaN count: 0, MiscFeature, object
# NaN count: 0, MiscVal, int64
# NaN count: 0, MoSold, int64
# NaN count: 0, YrSold, int64
# NaN count: 0, SaleType, object
# NaN count: 0, SaleCondition, object
# NaN count: 0, SalePrice, int64

# %%
list_data(df)
# Out:
# SubClass_20     1079
# SubClass_60      575
# SubClass_50      287
# SubClass_120     192
# SubClass_30      139
# SubClass_160     129
# SubClass_70      128
# SubClass_80      118
# SubClass_90      109
# SubClass_190      61
# SubClass_85       48
# SubClass_75       23
# SubClass_45       18
# SubClass_180      17
# SubClass_40        6
# SubClass_150       1
# Name: MSSubClass, dtype: int64
# RL         2273
# RM          462
# FV          139
# RH           27
# C (all)      25
# A (agr)       2
# I (all)       2
# Name: MSZoning, dtype: int64
# count    2930.000000
# mean       71.120287
# std        29.971931
# min        21.000000
# 25%        60.000000
# 50%        69.760416
# 75%        80.000000
# max       688.064377
# Name: LotFrontage, dtype: float64
# count      2930.000000
# mean      10147.921843
# std        7880.017759
# min        1300.000000
# 25%        7440.250000
# 50%        9436.500000
# 75%       11555.250000
# max      215245.000000
# Name: LotArea, dtype: float64
# count    2930.000000
# mean        0.995904
# std         0.063876
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Street, dtype: float64
# NoAlley    2732
# Grvl        120
# Pave         78
# Name: Alley, dtype: int64
# Reg    1859
# IR1     979
# IR2      76
# IR3      16
# Name: LotShape, dtype: int64
# Lvl    2633
# HLS     120
# Bnk     117
# Low      60
# Name: LandContour, dtype: int64
# count    2930.000000
# mean        0.998976
# std         0.031987
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Utilities, dtype: float64
# Inside     2140
# Corner      511
# CulDSac     180
# FR2          85
# FR3          14
# Name: LotConfig, dtype: int64
# Gtl    2789
# Mod     125
# Sev      16
# Name: LandSlope, dtype: int64
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# NWAmes     131
# SawyerW    125
# Mitchel    114
# BrkSide    108
# Crawfor    103
# IDOTRR      93
# Timber      72
# NoRidge     71
# StoneBr     51
# SWISU       48
# ClearCr     44
# MeadowV     37
# BrDale      30
# Blmngtn     28
# Veenker     24
# NPkVill     23
# Blueste     10
# Greens       8
# GrnHill      2
# Landmrk      1
# Name: Neighborhood, dtype: int64
# Norm      2522
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# RRNn         9
# RRNe         6
# Name: Condition1, dtype: int64
# Norm      2900
# Feedr       13
# Artery       5
# PosA         4
# PosN         4
# RRNn         2
# RRAe         1
# RRAn         1
# Name: Condition2, dtype: int64
# 1Fam      2425
# TwnhsE     233
# Duplex     109
# Twnhs      101
# 2fmCon      62
# Name: BldgType, dtype: int64
# 1Story    1481
# 2Story     873
# 1.5Fin     314
# SLvl       128
# SFoyer      83
# 2.5Unf      24
# 1.5Unf      19
# 2.5Fin       8
# Name: HouseStyle, dtype: int64
# count    2930.000000
# mean        6.094881
# std         1.411026
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64
# count    2930.000000
# mean        5.563140
# std         1.111537
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: OverallCond, dtype: float64
# count    2930.000000
# mean     1971.356314
# std        30.245361
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2001.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64
# count    2930.000000
# mean     1984.266553
# std        20.860286
# min      1950.000000
# 25%      1965.000000
# 50%      1993.000000
# 75%      2004.000000
# max      2010.000000
# Name: YearRemodAdd, dtype: float64
# Gable      2321
# Hip         551
# Gambrel      22
# Flat         20
# Mansard      11
# Shed          5
# Name: RoofStyle, dtype: int64
# CompShg    2887
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# ClyTile       1
# Membran       1
# Metal         1
# Roll          1
# Name: RoofMatl, dtype: int64
# VinylSd    1026
# MetalSd     450
# HdBoard     442
# Wd Sdng     420
# Plywood     221
# CemntBd     126
# BrkFace      88
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# CBlock        2
# Stone         2
# PreCast       1
# ImStucc       1
# Name: Exterior1st, dtype: int64
# VinylSd    1015
# MetalSd     447
# HdBoard     406
# Wd Sdng     397
# Plywood     274
# CmentBd     126
# Wd Shng      81
# BrkFace      47
# Stucco       47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# PreCast       1
# Name: Exterior2nd, dtype: int64
# None       1775
# BrkFace     880
# Stone       249
# BrkCmn       25
# CBlock        1
# Name: MasVnrType, dtype: int64
# count    2930.000000
# mean      100.676451
# std       178.509059
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       162.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64
# count    2930.000000
# mean        3.398635
# std         0.580317
# min         2.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: ExterQual, dtype: float64
# count    2930.000000
# mean        3.085324
# std         0.371698
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: ExterCond, dtype: float64
# PConc     1310
# CBlock    1244
# BrkTil     311
# Slab        49
# Stone       11
# Wood         5
# Name: Foundation, dtype: int64
# count    2930.000000
# mean        3.478840
# std         0.904295
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: BsmtQual, dtype: float64
# count    2930.000000
# mean        2.922867
# std         0.572670
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: BsmtCond, dtype: float64
# count    2930.000000
# mean        0.657679
# std         1.045181
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: BsmtExposure, dtype: float64
# GLQ       859
# Unf       851
# ALQ       429
# Rec       288
# BLQ       269
# LwQ       154
# NoBsmt     80
# Name: BsmtFinType1, dtype: int64
# count    2930.000000
# mean      442.478498
# std       455.586452
# min         0.000000
# 25%         0.000000
# 50%       370.000000
# 75%       734.000000
# max      5644.000000
# Name: BsmtFinSF1, dtype: float64
# Unf       2499
# Rec        106
# LwQ         89
# NoBsmt      81
# BLQ         68
# ALQ         53
# GLQ         34
# Name: BsmtFinType2, dtype: int64
# count    2930.000000
# mean       49.541980
# std       168.958405
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1526.000000
# Name: BsmtFinSF2, dtype: float64
# count    2930.000000
# mean      559.071672
# std       439.540571
# min         0.000000
# 25%       219.000000
# 50%       465.500000
# 75%       801.750000
# max      2336.000000
# Name: BsmtUnfSF, dtype: float64
# count    2930.000000
# mean     1051.255631
# std       440.968018
# min         0.000000
# 25%       793.000000
# 50%       990.000000
# 75%      1301.500000
# max      6110.000000
# Name: TotalBsmtSF, dtype: float64
# GasA     2885
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
# count    2930.000000
# mean        4.149488
# std         0.958070
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# Name: HeatingQC, dtype: float64
# Y    2734
# N     196
# Name: CentralAir, dtype: int64
# SBrkr    2683
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64
# count    2930.000000
# mean     1159.557679
# std       391.890885
# min       334.000000
# 25%       876.250000
# 50%      1084.000000
# 75%      1384.000000
# max      5095.000000
# Name: 1stFlrSF, dtype: float64
# count    2930.000000
# mean      335.455973
# std       428.395715
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       703.750000
# max      2065.000000
# Name: 2ndFlrSF, dtype: float64
# count    2930.000000
# mean        4.676792
# std        46.310510
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1064.000000
# Name: LowQualFinSF, dtype: float64
# count    2930.000000
# mean     1499.690444
# std       505.508887
# min       334.000000
# 25%      1126.000000
# 50%      1442.000000
# 75%      1742.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64
# count    2930.000000
# mean        0.431058
# std         0.524762
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: BsmtFullBath, dtype: float64
# count    2930.000000
# mean        0.061092
# std         0.245175
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: BsmtHalfBath, dtype: float64
# count    2930.000000
# mean        1.566553
# std         0.552941
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: FullBath, dtype: float64
# count    2930.000000
# mean        0.379522
# std         0.502629
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         2.000000
# Name: HalfBath, dtype: float64
# count    2930.000000
# mean        2.854266
# std         0.827731
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         8.000000
# Name: BedroomAbvGr, dtype: float64
# count    2930.000000
# mean        1.044369
# std         0.214076
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: KitchenAbvGr, dtype: float64
# count    2930.000000
# mean        3.511263
# std         0.663162
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: KitchenQual, dtype: float64
# count    2930.000000
# mean        6.443003
# std         1.572964
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        15.000000
# Name: TotRmsAbvGrd, dtype: float64
# count    2930.000000
# mean        0.109215
# std         0.480785
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         6.000000
# Name: Functional, dtype: float64
# count    2930.000000
# mean        0.599317
# std         0.647921
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000
# Name: Fireplaces, dtype: float64
# count    2930.000000
# mean        1.770307
# std         1.804968
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         4.000000
# max         5.000000
# Name: FireplaceQu, dtype: float64
# Attchd      1731
# Detchd       782
# BuiltIn      186
# NoGarage     157
# Basment       36
# 2Types        23
# CarPort       15
# Name: GarageType, dtype: int64
# count    2930.000000
# mean     1976.995229
# std        25.810505
# min      1895.000000
# 25%      1959.000000
# 50%      1978.000000
# 75%      2001.000000
# max      2207.000000
# Name: GarageYrBlt, dtype: float64
# Unf         1231
# RFn          812
# Fin          728
# NoGarage     159
# Name: GarageFinish, dtype: int64
# count    2930.000000
# mean        1.766894
# std         0.760449
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: GarageCars, dtype: float64
# count    2930.000000
# mean      472.801618
# std       215.012072
# min         0.000000
# 25%       320.000000
# 50%       480.000000
# 75%       576.000000
# max      1488.000000
# Name: GarageArea, dtype: float64
# count    2930.000000
# mean        2.801706
# std         0.714621
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: GarageQual, dtype: float64
# count    2930.000000
# mean        2.809556
# std         0.711255
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: GarageCond, dtype: float64
# Y    2652
# N     216
# P      62
# Name: PavedDrive, dtype: int64
# count    2930.000000
# mean       93.751877
# std       126.361562
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       168.000000
# max      1424.000000
# Name: WoodDeckSF, dtype: float64
# count    2930.000000
# mean       47.533447
# std        67.483400
# min         0.000000
# 25%         0.000000
# 50%        27.000000
# 75%        70.000000
# max       742.000000
# Name: OpenPorchSF, dtype: float64
# count    2930.000000
# mean       23.011604
# std        64.139059
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1012.000000
# Name: EnclosedPorch, dtype: float64
# count    2930.000000
# mean        2.592491
# std        25.141331
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       508.000000
# Name: 3SsnPorch, dtype: float64
# count    2930.000000
# mean       16.002048
# std        56.087370
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       576.000000
# Name: ScreenPorch, dtype: float64
# count    2930.000000
# mean        2.243345
# std        35.597181
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       800.000000
# Name: PoolArea, dtype: float64
# NoPool    2917
# Ex           4
# Gd           4
# TA           3
# Fa           2
# Name: PoolQC, dtype: int64
# count    2930.000000
# mean        0.273720
# std         0.596587
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: Fence, dtype: float64
# None    2824
# Shed      95
# Gar2       5
# Othr       4
# TenC       1
# Elev       1
# Name: MiscFeature, dtype: int64
# count     2930.000000
# mean        50.635154
# std        566.344288
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      17000.000000
# Name: MiscVal, dtype: float64
# count    2930.000000
# mean        6.216041
# std         2.714492
# min         1.000000
# 25%         4.000000
# 50%         6.000000
# 75%         8.000000
# max        12.000000
# Name: MoSold, dtype: float64
# count    2930.000000
# mean     2007.790444
# std         1.316613
# min      2006.000000
# 25%      2007.000000
# 50%      2008.000000
# 75%      2009.000000
# max      2010.000000
# Name: YrSold, dtype: float64
# WD       2536
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# VWD         1
# Name: SaleType, dtype: int64
# Normal     2413
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: SaleCondition, dtype: int64
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
